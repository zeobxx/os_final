# %% [markdown]
# **Ref:** https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d

# %% [markdown]
# การสร้าง Personal token
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###การลบ repository
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###การสร้าง Repository
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - echo "# os" >> README.md
# - git init
# - git add README.md
# - git commit -m "first commit"
# - git branch -M main
# - git remote add origin https://github.com/somnuk2/os.git
# - git push -u origin main

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ขั้นตอนการทำงาน
# 1. New personal access tokern
# - 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
#
# ### สร้าง folder ชื่อว่า github
# 1. mkdir github
# 2. cd github
# 3. copy file ไปที่ folder ชื่อว่า github
#
# ### การ uplaad ข้อมูลขึ้นไปสู่ GitHub
# 1. git init
# 2. git add .
# 3. git config --global user.email 'somnuk@mju.ac.th'
# 4. git config --global user.name 'somnuk2'
# 5. git commit -m "first commit"
# 6. git branch -M main
# 7. git remote add origin https://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@github.com/somnuk2/os.git
# 7. git remote -v
# 8. git push -u origin main
#
# ### การ clone ข้อมูลจาก GitHub
# 1. git clone https://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@github.com/somnuk2/os.git
# 2. cd os
# 3. git remote -v
# 4. echo "# os" >> README.md
# 5. git add .
# 6. git config --global user.email 'somnuk@mju.ac.th'
# 7. git config --global user.name 'somnuk2'
# 8. git commit -m "read.md"
# 9. git branch -M main
# 10. git push -u origin main
#
# ### การ update ข้อมูลจาก GitHub
# 1. git config --global user.email 'somnuk@mju.ac.th'
# 2. git config --global user.name 'somnuk2'
# 3. git branch -M main
# 4. git branch -r
# 5. git remote add origin https://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@github.com/somnuk2/os.git
# 6. git remote -v
# 7. git pull

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GitHub
# Out:
# /content/drive/MyDrive/GitHub

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GitHub

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/GitHub/.git/

# %%
# !git add .
#!git add --all

# %%
# !git config --global user.email 'somnuk@mju.ac.th'
# !git config --global user.name 'somnuk2'

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) aadff82] first commit
#  1 file changed, 567 insertions(+)
#  create mode 100644 C9_Lab1_3.ipynb

# %%
# !git branch -M main

# %%
username = 'somnuk2'
password = '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'#token
repository ='os'
print(f"https://{password}@github.com/{username}/{repository}.git")
# Out:
# https://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@github.com/somnuk2/os.git

# %%
# !git remote add origin https://{password}@github.com/{username}/{repository}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/somnuk2/os.git (fetch)
# origin	https://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@github.com/somnuk2/os.git (push)

# %%
# !git push -f origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 946.69 KiB | 9.96 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/somnuk2/os.git
#  * [new branch]      main -> main

# %%
# !echo "test GitHub with google colab and google drive">>READ.md

# %%
# !git add .

# %%
# !git commit -m "add READ.md"
# Out:
# [main 0f2c57f] add READ.md
#  1 file changed, 1 insertion(+)
#  create mode 100644 READ.md

# %%
# !git push -f origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 319 bytes | 106.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/somnuk2/os.git
#    aadff82..0f2c57f  main -> main

# %% [markdown]
# ### การ clone ข้อมูลจาก GitHub

# %%
# !pwd
# Out:
# /content/drive/My Drive/GitHub

# %%
# %cd ..
# !pwd
# Out:
# /content/drive/My Drive
# /content/drive/My Drive

# %%
username = 'somnuk2'
git_token = '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'#token
repository ='os'
print(f"https://{password}@github.com/{username}/{repository}.git")
# Out:
# https://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@github.com/somnuk2/os.git

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'os'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# %cd os
# Out:
# /content/drive/My Drive/os

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/somnuk2/os (fetch)
# origin	https://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@github.com/somnuk2/os (push)

# %%
#print("Hello GitHub")# in ipynb

# %%
# !git add .

# %%
# !git commit -m "updatet ipynb"
# Out:
# [main 2579f19] updatet ipynb
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite C9_Lab1_3.ipynb (64%)

# %%
# !git branch -M main

# %%
# !git push -f origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 397 bytes | 397.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/somnuk2/os
#    bb7ac43..2579f19  main -> main

# %% [markdown]
# ### การ update ข้อมูลจาก GitHub

# %%
# !pwd
# Out:
# /content/drive/My Drive/os

# %%
# %cd /content/drive/MyDrive/GitHub
# Out:
# /content/drive/MyDrive/GitHub

# %%
# !git config --global user.email 'somnuk@mju.ac.th'
# !git config --global user.name 'somnuk2'

# %%
# !git branch -M main

# %%
# !git branch -r
# Out:
#   origin/main

# %%
# !git remote add origin https://{password}@github.com/{username}/{repository}.git
# Out:
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/somnuk2/os.git (fetch)
# origin	https://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@github.com/somnuk2/os.git (push)

# %%
# !pwd
# Out:
# /content/drive/My Drive/GitHub

# %%
# !git pull origin main
# Out:
# From https://github.com/somnuk2/os
#  * branch            main       -> FETCH_HEAD
# Updating 0f2c57f..2579f19
# Fast-forward
#  C9_Lab1_3.ipynb | 568 +-------------------------------------------------------
#  READ.md         |   1 +
#  2 files changed, 2 insertions(+), 567 deletions(-)
